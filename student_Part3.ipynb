# %% [markdown]
# ## Part 3 Content
# * Import Libraries
# * Load myData CSV File
# * Q3: Which directors, writers, actors and actresses make the most profit (Medium Budget)?
# * Q4: Which genres make the most profit (Medium Budget)?
#
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from functions import *
# Out:
# /Users/kamileyagci/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## Load myData CSV File

# %%
#myData.csv file is created in Part 1 python file. It combined all required data.
df = pd.read_csv('zippedData/myData.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53305 entries, 0 to 53304
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         53305 non-null  int64
#  1   release_date       53305 non-null  object
#  2   movie              53305 non-null  object
#  3   production_budget  53305 non-null  float64
#  4   domestic_gross     53305 non-null  float64
#  5   worldwide_gross    53305 non-null  float64
#  6   tconst             53305 non-null  object
#  7   genres             53265 non-null  object
#  8   averagerating      53305 non-null  float64
#  9   numvotes           53305 non-null  int64
#  10  nconst             53305 non-null  object
#  11  category           53305 non-null  object
#  12  characters         21488 non-null  object
#  13  primary_name       53305 non-null  object
#  14  death_year         1243 non-null   float64
#  15  release_year       53305 non-null  int64
#  16  profit_gross       53305 non-null  float64
#  17  profit_rate        53305 non-null  float64
# dtypes: float64(7), int64(3), object(8)
# memory usage: 7.3+ MB

# %%
#df[df.primary_name =='Emma Thompson']

# %% [markdown]
# ## Q3: Which directors, writers, actors and actresses make the most profit? (Medium budget)

# %%
# Copy dataframe with selected columns
selected_columns2 = ['category', 'primary_name', 'death_year', 'movie', 'production_budget', 'profit_gross', 'profit_rate', 'release_year']
df2 = df[selected_columns2].copy() ## Select columns

# Clean duplicates
df2.drop_duplicates(subset=None, keep='first', inplace=True)

#Select the movies with production_budget > $100,000,000
df2 = df2[(df2.production_budget > 20000000) & (df2.production_budget <= 100000000)]

# Remove the dead people
df2 = df2[df2.death_year.isnull()]

#Drop the movies with release year before 1990
df2.drop(df2[df2.release_year < 1990].index, inplace=True)

print(df2.shape)
df2.head(20)
# Out:
# (8267, 8)
#              category                      primary_name  death_year  \
# 6397         producer                       Gary Barber         NaN
# 6398         producer                   Patrick Crowley         NaN
# 6399            actor                   Chris Hemsworth         NaN
# 6401         producer                      Barry Levine         NaN
# 6403         producer                         Riza Aziz         NaN
# 6405         director  Florian Henckel von Donnersmarck         NaN
# 6410            actor              Biswajit Chakraborty         NaN
# 6414            actor                    Joseph Fiennes         NaN
# 6418         director                      Brett Ratner         NaN
# 6420           writer                       Steve Moore         NaN
# 6423  cinematographer                     Supriyo Dutta         NaN
# 6424           writer                      Jérôme Salle         NaN
# 6425            actor             Parambrata Chatterjee         NaN
# 6427         producer                    Roger Birnbaum         NaN
# 6429         producer                   Shyamsundar Dey         NaN
# 6430          actress                         Paoli Dam         NaN
# 6431         producer                        Avi Lerner         NaN
# 6433         producer                        Avi Lerner         NaN
# 6436            actor                Sylvester Stallone         NaN
# 6438           writer                     James V. Hart         NaN
#
#                         movie  production_budget  profit_gross  profit_rate  \
# 6397              The Tourist        100000000.0   178731369.0     2.787314
# 6398           The Other Guys        100000000.0    70936470.0     1.709365
# 6399  In the Heart of the Sea        100000000.0   -10306691.0     0.896933
# 6401                 Hercules        100000000.0   143388614.0     2.433886
# 6403  The Wolf of Wall Street        100000000.0   289870414.0     3.898704
# 6405              The Tourist        100000000.0   178731369.0     2.787314
# 6410                 Hercules        100000000.0   143388614.0     2.433886
# 6414                 Hercules        100000000.0   143388614.0     2.433886
# 6418                 Hercules        100000000.0   143388614.0     2.433886
# 6420                 Hercules        100000000.0   143388614.0     2.433886
# 6423                 Hercules        100000000.0   143388614.0     2.433886
# 6424              The Tourist        100000000.0   178731369.0     2.787314
# 6425                 Hercules        100000000.0   143388614.0     2.433886
# 6427              The Tourist        100000000.0   178731369.0     2.787314
# 6429                 Hercules        100000000.0   143388614.0     2.433886
# 6430                 Hercules        100000000.0   143388614.0     2.433886
# 6431        The Expendables 2        100000000.0   211979256.0     3.119793
# 6433        The Expendables 3        100000000.0   109461378.0     2.094614
# 6436        The Expendables 2        100000000.0   211979256.0     3.119793
# 6438                     Epic        100000000.0   162794441.0     2.627944
#
#       release_year
# 6397          2010
# 6398          2010
# 6399          2015
# 6401          2014
# 6403          2013
# 6405          2010
# 6410          2014
# 6414          2014
# 6418          2014
# 6420          2014
# 6423          2014
# 6424          2010
# 6425          2014
# 6427          2010
# 6429          2014
# 6430          2014
# 6431          2012
# 6433          2014
# 6436          2012
# 6438          2013

# %%
# Director, call function
categoryStudy(df2, 'director', 15, 12, 'med')
# Out:
# Total number: 134
# Best director List:  ['Phil Lord', 'James Foley', 'Chris Renaud', 'Kyle Balda', 'Steve Martino', 'Paul Feig', 'Jake Kasdan', 'Christopher Miller', 'Genndy Tartakovsky', 'Pierre Coffin', 'Olivier Megaton']

# %%
# Writer, call function
categoryStudy(df2, 'writer', 20, 15, 'med')
# Out:
# Total number: 218
# Best writer List:  ['Robert Mark Kamen', 'Billy Ray', 'Stephenie Meyer', 'Anthony McCarten', 'Wellesley Wild', 'Alec Sulkin', 'Erik Sommers', 'Niall Leonard', 'Brian Lynch', 'Craig Mazin', 'Kevin Hageman', 'Ken Daurio', 'Chris McKenna', 'Dan Hageman', 'Cinco Paul', 'E.L. James']

# %%
df2[df2.primary_name == 'Chris Renaud']
# Out:
#        category  primary_name  death_year                      movie  \
# 8555   director  Chris Renaud         NaN  The Secret Life of Pets 2
# 9014   director  Chris Renaud         NaN            Despicable Me 2
# 9061   director  Chris Renaud         NaN    The Secret Life of Pets
# 10238  director  Chris Renaud         NaN              Despicable Me
#
#        production_budget  profit_gross  profit_rate  release_year
# 8555          80000000.0    33351496.0     1.416894          2019
# 9014          76000000.0   899216835.0    12.831800          2013
# 9061          75000000.0   811750534.0    11.823340          2016
# 10238         69000000.0   474464573.0     7.876298          2010

# %%
# Actor, call function
categoryStudy(df2, 'actor', 20, 15, 'med')
# Out:
# Total number: 321
# Best actor List:  ['Benjamin Bratt', 'Aziz Ansari', 'Thomas Brodie-Sangster', 'Denis Leary', 'Taylor Lautner', 'Ed Skrein', 'Bradley Cooper', 'Eric Johnson', 'Eric Stonestreet', 'Andy Samberg', 'Seth MacFarlane', 'Jamie Dornan', 'Michael Keaton', 'Neil Patrick Harris', 'Marwan Kenzari', "Dylan O'Brien"]

# %%
# Actress, call function
categoryStudy(df2, 'actress', 15, 10, 'med')
# Out:
# Total number: 167
# Best actress List:  ['Famke Janssen', 'Eloise Mumford', 'Dakota Johnson', 'Jennifer Ehle', 'Miranda Cosgrove', 'Jennifer Lawrence', 'Kristen Wiig', 'Hailee Steinfeld', 'Ali Larter', 'Sandra Bullock', 'Selena Gomez']

# %% [markdown]
# ## Q4: Which genre brings highest profit? (medium budget)

# %%
# Copy dataframe with selected columns
selected_columns3 = ['movie', 'production_budget', 'genres', 'profit_gross', 'profit_rate', 'release_year']
df3 = df[selected_columns3].copy() ## Select columns

# Clean duplicates
df3.drop_duplicates(subset=None, keep='first', inplace=True)

#Select the movies with production_budget > $100,000,000
df3 = df3[(df3.production_budget > 20000000) & (df3.production_budget <= 100000000)]

#Drop the movies with release date before 1990
df3.drop(df3[df3.release_year < 1990].index, inplace=True)

print(df3.shape)
df3.head(20)
# Out:
# (2019, 6)
#                         movie  production_budget     genres  profit_gross  \
# 6397              The Tourist        100000000.0     Action   178731369.0
# 6398           The Other Guys        100000000.0      Crime    70936470.0
# 6399  In the Heart of the Sea        100000000.0  Adventure   -10306691.0
# 6400  In the Heart of the Sea        100000000.0     Action   -10306691.0
# 6401                 Hercules        100000000.0  Adventure   143388614.0
# 6402                 Hercules        100000000.0     Action   143388614.0
# 6403  The Wolf of Wall Street        100000000.0      Crime   289870414.0
# 6404           The Other Guys        100000000.0     Action    70936470.0
# 6406              The Tourist        100000000.0   Thriller   178731369.0
# 6407              The Tourist        100000000.0  Adventure   178731369.0
# 6408                 Hercules        100000000.0    Fantasy   143388614.0
# 6409  In the Heart of the Sea        100000000.0  Biography   -10306691.0
# 6410                 Hercules        100000000.0     Comedy   143388614.0
# 6416           The Other Guys        100000000.0     Comedy    70936470.0
# 6431        The Expendables 2        100000000.0  Adventure   211979256.0
# 6432        The Expendables 2        100000000.0   Thriller   211979256.0
# 6433        The Expendables 3        100000000.0     Action   109461378.0
# 6434        The Expendables 3        100000000.0  Adventure   109461378.0
# 6435        The Expendables 3        100000000.0   Thriller   109461378.0
# 6436        The Expendables 2        100000000.0     Action   211979256.0
#
#       profit_rate  release_year
# 6397     2.787314          2010
# 6398     1.709365          2010
# 6399     0.896933          2015
# 6400     0.896933          2015
# 6401     2.433886          2014
# 6402     2.433886          2014
# 6403     3.898704          2013
# 6404     1.709365          2010
# 6406     2.787314          2010
# 6407     2.787314          2010
# 6408     2.433886          2014
# 6409     0.896933          2015
# 6410     2.433886          2014
# 6416     1.709365          2010
# 6431     3.119793          2012
# 6432     3.119793          2012
# 6433     2.094614          2014
# 6434     2.094614          2014
# 6435     2.094614          2014
# 6436     3.119793          2012

# %%
# Plot genres
genre_series1 = df3.groupby('genres')['profit_gross'].median().sort_values(ascending=False)
genre_series2 = df3.groupby('genres')['profit_rate'].median().sort_values(ascending=False)

fig, axes = plt.subplots(1, 2, figsize=(20, 15))
plt.subplots_adjust(wspace=0.4)
sns.set(font_scale=1.5)

genre_series1.plot.barh(ax=axes[0])
axes[0].set_title('Median Profit per Genre ($20,000,000 < Production Budget <= $100,000,000)', fontsize=15)
axes[0].set_xlabel('Median Profit')
axes[0].set_ylabel('Genres')

genre_series2.plot.barh(ax=axes[1], color='green')
axes[1].set_title('Median Profit Rate per Genre ($20,000,000 < Production Budget <= $100,000,000)', fontsize=15)
axes[1].set_xlabel('Median Profit Rate')
axes[1].set_ylabel('Genres')

plt.savefig('figures/genres-profit1_medBudget.png')

# %%
df3.groupby('genres').count().sort_values(by='movie', ascending=False)
# Out:
#              movie  production_budget  profit_gross  profit_rate  release_year
# genres
# Drama          366                366           366          366           366
# Comedy         272                272           272          272           272
# Action         265                265           265          265           265
# Adventure      168                168           168          168           168
# Thriller       157                157           157          157           157
# Crime          150                150           150          150           150
# Romance         85                 85            85           85            85
# Biography       84                 84            84           84            84
# Horror          66                 66            66           66            66
# Mystery         62                 62            62           62            62
# Animation       58                 58            58           58            58
# Fantasy         54                 54            54           54            54
# Sci-Fi          54                 54            54           54            54
# Family          45                 45            45           45            45
# Documentary     44                 44            44           44            44
# History         29                 29            29           29            29
# Sport           20                 20            20           20            20
# Music           18                 18            18           18            18
# War              9                  9             9            9             9
# Western          6                  6             6            6             6
# Musical          4                  4             4            4             4
# News             1                  1             1            1             1

# %%
#df3[df3.genres == 'Music']

# %%
# Select the popular genres names with higher number of movies
popular_genres = list(df3.groupby('genres').count().sort_values(by='movie', ascending=False)[0:18].index)
popular_genres
# Out:
# ['Drama',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Crime',
#  'Romance',
#  'Biography',
#  'Horror',
#  'Mystery',
#  'Animation',
#  'Fantasy',
#  'Sci-Fi',
#  'Family',
#  'Documentary',
#  'History',
#  'Sport',
#  'Music']

# %%
# Filter the data for the popular genres
df3_pop = df3.loc[df3['genres'].isin(popular_genres)]
df3_pop
# Out:
#                          movie  production_budget     genres  profit_gross  \
# 6397               The Tourist        100000000.0     Action   178731369.0
# 6398            The Other Guys        100000000.0      Crime    70936470.0
# 6399   In the Heart of the Sea        100000000.0  Adventure   -10306691.0
# 6400   In the Heart of the Sea        100000000.0     Action   -10306691.0
# 6401                  Hercules        100000000.0  Adventure   143388614.0
# ...                        ...                ...        ...           ...
# 26849                   Kidnap         21000000.0      Drama    13836080.0
# 26862                   Kidnap         21000000.0      Crime    13836080.0
# 27021                    Pulse         20500000.0    Fantasy     9741435.0
# 27022                    Pulse         20500000.0      Drama     9741435.0
# 27025                    Pulse         20500000.0     Sci-Fi     9741435.0
#
#        profit_rate  release_year
# 6397      2.787314          2010
# 6398      1.709365          2010
# 6399      0.896933          2015
# 6400      0.896933          2015
# 6401      2.433886          2014
# ...            ...           ...
# 26849     1.658861          2017
# 26862     1.658861          2017
# 27021     1.475192          2006
# 27022     1.475192          2006
# 27025     1.475192          2006
#
# [1997 rows x 6 columns]

# %%
# plots for popular genres
genre_series1 = df3_pop.groupby('genres')['profit_gross'].median().sort_values(ascending=False)
genre_series2 = df3_pop.groupby('genres')['profit_rate'].median().sort_values(ascending=False)

fig, axes = plt.subplots(1, 2, figsize=(20, 12))
plt.subplots_adjust(wspace=0.4)
sns.set(font_scale=1.5)

genre_series1.plot.barh(ax=axes[0])
axes[0].set_title('Median Profit per Popular Genres ($20,000,000 < Production Budget <= $100,000,000)', fontsize=15)
axes[0].set_xlabel('Median Profit')
axes[0].set_ylabel('Genres')

genre_series2.plot.barh(ax=axes[1], color='green')
axes[1].set_title('Median Profit Rate per Popular Genres ($20,000,000 < Production Budget <= $100,000,000)', fontsize=15)
axes[1].set_xlabel('Median Profit Rate')
axes[1].set_ylabel('Genres')

plt.savefig('figures/genres-profit2_medBudget.png')
